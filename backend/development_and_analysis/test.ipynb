# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5ADzvGdu4blAVrKyRPYy")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: roboflow in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (1.2.9)
# Requirement already satisfied: certifi in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (3.10.6)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (2.2.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\loq\appdata\roaming\python\python313\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in c:\users\loq\appdata\roaming\python\python313\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\loq\appdata\roaming\python\python313\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->roboflow) (4.60.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\loq\appdata\roaming\python\python313\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->roboflow) (3.2.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from requests->roboflow) (3.4.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov8:: 100%|██████████| 148663/148663 [01:13<00:00, 2032.33it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:00<00:00, 2597.26it/s]

# %%
# !pip install albumentations opencv-python numpy
# Out:
# Collecting albumentations
#   Using cached albumentations-2.0.8-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: opencv-python in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from albumentations) (1.16.2)
# Requirement already satisfied: PyYAML in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from albumentations) (2.12.3)
# Collecting albucore==0.0.24 (from albumentations)
#   Using cached albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from albumentations) (4.10.0.84)
# Collecting stringzilla>=3.10.4 (from albucore==0.0.24->albumentations)
#   Downloading stringzilla-4.2.3-cp313-cp313-win_amd64.whl.metadata (112 kB)
# Collecting simsimd>=5.9.2 (from albucore==0.0.24->albumentations)
#   Using cached simsimd-6.5.3-cp313-cp313-win_amd64.whl.metadata (71 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.9.2->albumentations) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Using cached albumentations-2.0.8-py3-none-any.whl (369 kB)
# Using cached albucore-0.0.24-py3-none-any.whl (15 kB)
# Using cached simsimd-6.5.3-cp313-cp313-win_amd64.whl (94 kB)
# Downloading stringzilla-4.2.3-cp313-cp313-win_amd64.whl (116 kB)
# Installing collected packages: simsimd, stringzilla, albucore, albumentations
#
#    ------------------------------ --------- 3/4 [albumentations]
#    ------------------------------ --------- 3/4 [albumentations]
#    ---------------------------------------- 4/4 [albumentations]
#
# Successfully installed albucore-0.0.24 albumentations-2.0.8 simsimd-6.5.3 stringzilla-4.2.3
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import os
import albumentations as A
import numpy as np

# Define input and output paths
input_images = r"D:\Football-analysis-project\backend\development_and_analysis\football-players-detection-1\train\images"
input_labels = r"D:\Football-analysis-project\backend\development_and_analysis\football-players-detection-1\train\labels"

output_images = r"D:\Football-analysis-project\backend\development_and_analysis\football-players-detection-1\train\augmented_images"
output_labels = r"D:\Football-analysis-project\backend\development_and_analysis\football-players-detection-1\train\augmented_labels"

# Create output folders if they don't exist
os.makedirs(output_images, exist_ok=True)
os.makedirs(output_labels, exist_ok=True)

# Define augmentation pipeline (applies to both images & bounding boxes)
augmentations = A.Compose([
    A.RandomRotate90(p=0.5),  # Rotate 90° randomly
    A.HorizontalFlip(p=0.5),  # Flip horizontally
    A.VerticalFlip(p=0.2),  # Flip vertically
    A.RandomBrightnessContrast(p=0.3),  # Adjust brightness/contrast to highlight the ball
    A.MotionBlur(blur_limit=3, p=0.2),  # Simulate motion blur
    A.GaussianBlur(blur_limit=3, p=0.2),  # Slight blur to account for low-quality frames
    A.RandomScale(scale_limit=0.3, p=0.5),  # Increase size of small objects
    A.RandomResizedCrop((640, 640), scale=(0.6, 1.0), ratio=(0.75, 1.33), p=0.3),  # ✅ Fixed RandomResizedCrop
    A.CLAHE(clip_limit=2.0, tile_grid_size=(8, 8), p=0.2),  # Improves contrast for small objects
    A.ToGray(p=0.1)  # Convert some images to grayscale (simulates different lighting conditions)
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))

# Loop through each image and its corresponding label
for img_file in os.listdir(input_images):
    if img_file.endswith((".jpg", ".png", ".jpeg")):
        # Load image
        img_path = os.path.join(input_images, img_file)
        image = cv2.imread(img_path)

        # Load YOLO label
        label_path = os.path.join(input_labels, img_file.replace(".jpg", ".txt").replace(".png", ".txt"))
        if not os.path.exists(label_path):
            continue  # Skip images without labels

        with open(label_path, "r") as f:
            lines = f.readlines()

        # Parse bounding boxes
        bboxes = []
        class_labels = []
        for line in lines:
            parts = line.strip().split()
            class_id = int(parts[0])
            bbox = list(map(float, parts[1:]))  # X_center, Y_center, Width, Height
            bboxes.append(bbox)
            class_labels.append(class_id)

        # Apply augmentation
        augmented = augmentations(image=image, bboxes=bboxes, class_labels=class_labels)

        # Save augmented image
        aug_img_path = os.path.join(output_images, f"aug_{img_file}")
        cv2.imwrite(aug_img_path, augmented["image"])

        # Save augmented labels
        aug_label_path = os.path.join(output_labels, f"aug_{img_file.replace('.jpg', '.txt').replace('.png', '.txt')}")
        with open(aug_label_path, "w") as f:
            for bbox, cls in zip(augmented["bboxes"], augmented["class_labels"]):
                f.write(f"{cls} " + " ".join(map(str, bbox)) + "\n")

print("✅ Data augmentation with bounding boxes completed!")
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 32
#      18 augmentations = A.Compose([
#      19     A.RandomRotate90(p=0.5),  # Rotate 90° randomly
#      20     A.HorizontalFlip(p=0.5),  # Flip horizontally
#    (...)     28     A.ToGray(p=0.1)  # Convert some images to grayscale (simulates different lighting conditions)
#      29 ], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))
#      31 # Loop through each image and its corresponding label
# ---> 32 for img_file in os.listdir(input_images):
#      33     if img_file.endswith((".jpg", ".png", ".jpeg")):
#      34         # Load image
#      35         img_path = os.path.join(input_images, img_file)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\project_test\\development_and_analysis\\football-players-detection-1\\train\\images'

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (8.3.201)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil in c:\users\loq\appdata\roaming\python\python313\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (1.33.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\loq\appdata\roaming\python\python313\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\loq\appdata\roaming\python\python313\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\loq\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\loq\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
